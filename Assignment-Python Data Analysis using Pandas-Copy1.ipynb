# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Practice Problems

# %%
#load iris data 
Iris = pd.read_csv (r"D:\Desktop\Iris.csv")

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 126  127            6.2           2.8            4.8           1.8
# 33    34            5.5           4.2            1.4           0.2
# 44    45            5.1           3.8            1.9           0.4
# 17    18            5.1           3.5            1.4           0.3
# 5      6            5.4           3.9            1.7           0.4
# 72    73            6.3           2.5            4.9           1.5
# 147  148            6.5           3.0            5.2           2.0
# 109  110            7.2           3.6            6.1           2.5
# 2      3            4.7           3.2            1.3           0.2
# 64    65            5.6           2.9            3.6           1.3
#
#              Species
# 126   Iris-virginica
# 33       Iris-setosa
# 44       Iris-setosa
# 17       Iris-setosa
# 5        Iris-setosa
# 72   Iris-versicolor
# 147   Iris-virginica
# 109   Iris-virginica
# 2        Iris-setosa
# ...

# %%
Iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
pd.set_option('display.max_row',1000)
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %% [markdown]
# ### View the data

# %%
# Qn 1. How many rows does the dataframe contain?
Iris.shape
#here 150 represents the rows and 6 represents the column.
# Out:
# (150, 6)

# %%
# Qn 2. How many rows that have species setosa?
Iris['Species'].value_counts()
#there are 50 rows of species setosa.
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# Qn 3.What are the data types of the columns?
Iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Qn 4. What all species are there in the dataset?
print(Iris['Species'].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %% [markdown]
# ### Indexing

# %%
#Qn 5. if sepal_length is greater than 5, multiply it by 100
for number in Iris.SepalLengthCm:
    if (number > 5.0):
        print (number*100)
    else:
        print(number)
# Out:
# 509.99999999999994
# 4.9
# 4.7
# 4.6
# 5.0
# 540.0
# 4.6
# 5.0
# 4.4
# 4.9
# 540.0
# 4.8
# 4.8
# 4.3
# 580.0
# 570.0
# 540.0
# 509.99999999999994
# 570.0
# 509.99999999999994
# 540.0
# 509.99999999999994
# 4.6
# 509.99999999999994
# 4.8
# 5.0
# 5.0
# 520.0
# 520.0
# 4.7
# 4.8
# 540.0
# 520.0
# 550.0
# 4.9
# 5.0
# 550.0
# 4.9
# 4.4
# 509.99999999999994
# 5.0
# 4.5
# 4.4
# 5.0
# 509.99999999999994
# 4.8
# 509.99999999999994
# 4.6
# 530.0
# 5.0
# 700.0
# 640.0
# 690.0
# 550.0
# 650.0
# 570.0
# 630.0
# 4.9
# 660.0
# 520.0
# 5.0
# 590.0
# 600.0
# 610.0
# 560.0
# 670.0
# 560.0
# 580.0
# 620.0
# 560.0
# 590.0
# 610.0
# 630.0
# 610.0
# 640.0
# 660.0
# 680.0
# 670.0
# 600.0
# 570.0
# 550.0
# 550.0
# 580.0
# 600.0
# 540.0
# 600.0
# 670.0
# 630.0
# 560.0
# 550.0
# 550.0
# 610.0
# 580.0
# 5.0
# 560.0
# 570.0
# 570.0
# 620.0
# 509.99999999999994
# 570.0
# 630.0
# 580.0
# 710.0
# 630.0
# 650.0
# 760.0
# 4.9
# 730.0
# 670.0
# 720.0
# 650.0
# 640.0
# 680.0
# 570.0
# 580.0
# 640.0
# 650.0
# 770.0
# ...

# %%
#Qn 6. Find the sum of sepal_length for all the values where species is sentosa
Iris.SepalLengthCm.head(50).sum()
# Out:
# 250.3

# %%
#Qn 7. Find mean petal_length for versicolor
Iris.PetalLengthCm[50:100].mean()
# Out:
# 4.26

# %%
#Qn 8. Find maximum sepal_width for virginica
Iris.SepalWidthCm[100:150].max()
# Out:
# 3.8

# %%
# Qn 9. Add a new column to the iris dataframe called 'sepal' which should be 'wide' if sepal_width is greater than 3,
# else narrow.
for i in Iris.SepalWidthCm:
    if i >3:
        print('Wide')
    else:
        print('Narrow')
# Out:
# Wide
# Narrow
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Narrow
# Wide
# Wide
# Wide
# Narrow
# Narrow
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Narrow
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Narrow
# Wide
# Wide
# Narrow
# Wide
# Wide
# Wide
# Narrow
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Wide
# Narrow
# Narrow
# Narrow
# Wide
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Wide
# Narrow
# Narrow
# Narrow
# Narrow
# Wide
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Wide
# Wide
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Wide
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Narrow
# Wide
# Wide
# Narrow
# Narrow
# Narrow
# Narrow
# Wide
# Narrow
# Wide
# Narrow
# Narrow
# Wide
# Narrow
# Narrow
# ...

# %% [markdown]
# ### Missing Data

# %%
# Qn 10. Fill the missing values with 0
Iris = Iris.fillna(0)

# %%
# Qn 11. Fill the missing values only in sepal_length with 0
Iris['SepalLengthCm'] = Iris['SepalLengthCm'].fillna(0)

# %%
# Qn 12. Fill the missing values with non-NaN previous values
Iris.ffill(inplace=True)

# %%
# Qn 13. Fill the missing values in all columns with sepal with non-NaN previous values and all columns with 
# petal with next non-NaN value
Iris['SepalLengthCm'].ffill(inplace=True)
Iris['SepalWidthCm'].ffill(inplace=True)

# %%
# Qn 14. Replace species names using dictionary.
d = {'setosa': 'se', 'virginica': 'vi', 'versicolor': 've'}

# %%
# Qn 15. Set the species column as index
Iris.set_index('Species')
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            5.1           3.5            1.4           0.2
# Iris-setosa        2            4.9           3.0            1.4           0.2
# Iris-setosa        3            4.7           3.2            1.3           0.2
# Iris-setosa        4            4.6           3.1            1.5           0.2
# Iris-setosa        5            5.0           3.6            1.4           0.2
# Iris-setosa        6            5.4           3.9            1.7           0.4
# Iris-setosa        7            4.6           3.4            1.4           0.3
# Iris-setosa        8            5.0           3.4            1.5           0.2
# Iris-setosa        9            4.4           2.9            1.4           0.2
# Iris-setosa       10            4.9           3.1            1.5           0.1
# Iris-setosa       11            5.4           3.7            1.5           0.2
# ...

# %% [markdown]
# ### Operations

# %%
# Qn 16. Find mean sepal length
Iris['SepalLengthCm'].mean()
# Out:
# 5.843333333333335

# %%
# Qn 17. Find minimum petal width
Iris['PetalWidthCm'].min()
# Out:
# 0.1

# %%
# Qn 18. Add a row mean at the end of the dataframe with mean values for each column
pd.pivot_table(Iris,index ='Species',values=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],aggfunc=np.mean,margins=True)
# Out:
#                  PetalLengthCm  PetalWidthCm  SepalLengthCm  SepalWidthCm
# Species
# Iris-setosa           1.464000      0.244000       5.006000         3.418
# Iris-versicolor       4.260000      1.326000       5.936000         2.770
# Iris-virginica        5.552000      2.026000       6.588000         2.974
# All                   3.758667      1.198667       5.843333         3.054

# %%
# Qn 19. Add column sum with sum of both widths and lengths
Iris['Column sum'] = Iris['SepalLengthCm']+Iris['SepalWidthCm']+Iris['PetalLengthCm']+Iris['PetalLengthCm']
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
# Qn 20. Find sum of sepal_length, sepal_width, petal_length, petal_width by species

pd.pivot_table(Iris,index ='Species',values=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],aggfunc=np.sum)
# Out:
#                  PetalLengthCm  PetalWidthCm  SepalLengthCm  SepalWidthCm
# Species
# Iris-setosa               73.2          12.2          250.3         170.9
# Iris-versicolor          213.0          66.3          296.8         138.5
# Iris-virginica           277.6         101.3          329.4         148.7

# %%
# Qn 21. Find sum of sepal_length and mean petal_length
Iris['SepalLengthCm'].sum() + Iris['PetalLengthCm'].mean()
# Out:
# 880.2586666666666
